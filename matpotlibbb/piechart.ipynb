# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = [1,3,7,5,3,2]
labels = [1,3,7,5,3,2]
plt.pie(data,labels=labels,autopct="%0.1f")

# %%
df = pd.read_csv(r"C:\Users\Pranav Wadatkar\Desktop\Python\structured-learning\data\matplot\gayle-175.csv")
df
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %%
plt.pie(df["batsman_runs"],labels=df["batsman"],autopct="%0.1f")

# %%
plt.pie(df["batsman_runs"],labels=df["batsman"],autopct="%0.1f",explode=[0.1,0,0,0,0,0],shadow=True)
