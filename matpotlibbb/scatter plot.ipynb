# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Pranav Wadatkar\Desktop\Python\structured-learning\data\matplot\batter.csv")

#scatter plot is mainly used to find correlation between 2 parameters
x = np.linspace(-10,10,50)
y = 10*x + 3 + np.random.randint(0,300,50)

plt.scatter(x,y)

# %%
df
df = df.head(50)

# %%
plt.scatter(df["avg"],df["strike_rate"],marker="+")
plt.title("Batsman Analysis")
plt.xlabel("Avg")
plt.ylabel("Strike Rate")
plt.grid()
plt.show()

#executes faster
plt.plot(df["avg"],df["strike_rate"],"+")
plt.grid()
